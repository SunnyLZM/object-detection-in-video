# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d5d152a5-4c75-4e2a-8e34-93572eb7e194" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d5d152a5-4c75-4e2a-8e34-93572eb7e194">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# If you uploaded multiple files, this will just handle the first one
video_filename = list(uploaded.keys())[0]
print(f"Uploaded file: {video_filename}")
import os
# Rename the uploaded file to a simpler name
new_video_name = "input_video.mp4"
os.rename(video_filename, new_video_name)
print(f"Renamed '{video_filename}' to '{new_video_name}'")

# Verify the file is in the current directory
print("Current directory contents:")
# !ls -lh
# Out:
# Uploaded file: synthetic_human (4).mp4
# Renamed 'synthetic_human (4).mp4' to 'input_video.mp4'
# Current directory contents:
# total 444K
# -rw-r--r-- 1 root root 439K Mar 18 00:55 input_video.mp4
# drwxr-xr-x 1 root root 4.0K Mar 14 13:32 sample_data

# %%
# !pip install --upgrade pip
# !pip install opencv-python opencv-python-headless numpy matplotlib torch torchvision
# !git clone https://github.com/ultralytics/yolov5.git
# !pip install -r yolov5/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 30.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 29.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 62.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 50.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 67.5 MB/s eta 0:00:00
# ...

# %%
import cv2
import torch
import numpy as np
from IPython.display import Video, display

# %% [markdown]
# # Step 1: Download a YouTube video

# %%
print("Loading YOLOv5 model...")
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', trust_repo=True)  # pretrained on COCO
model.eval()
print("Model loaded successfully!")
# Out:
# Loading YOLOv5 model...
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLOv5 🚀 2025-3-18 Python-3.11.11 torch-2.6.0+cu124 CPU
#
# ...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 87.9MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# Model loaded successfully!

# %% [markdown]
# # Step 2: Load the YOLOv5 model (pretrained on COCO)

# %%
print("Loading YOLOv5 model...")
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', trust_repo=True)
model.eval()
print("Model loaded successfully!")

# COCO dataset class names (80 classes)
COCO_CLASSES = [
    'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train',
    'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter',
    'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear',
    'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase',
    'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat',
    'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle',
    'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple',
    'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut',
    'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet',
    'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave',
    'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
    'teddy bear', 'hair drier', 'toothbrush'
]
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-3-18 Python-3.11.11 torch-2.6.0+cu124 CPU
# Loading YOLOv5 model...
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# Model loaded successfully!

# %% [markdown]
# # Step 3: Detect objects and annotate the video

# %%
def detect_and_annotate_video(input_path="input_video.mp4", output_path="output_tracking.mp4"):
    """
    Process the input video frame by frame.
    Use YOLOv5 to detect objects, annotate each detection with its COCO class label,
    and generate an output video with the annotations.
    """
    if not os.path.exists(input_path):
        print(f"Error: Video file '{input_path}' does not exist.")
        return

    cap = cv2.VideoCapture(input_path)
    if not cap.isOpened():
        print(f"Error: Could not open video file '{input_path}'")
        return

    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS) if cap.get(cv2.CAP_PROP_FPS) > 0 else 30  # fallback if FPS=0
    print(f"Video properties: {frame_width}x{frame_height} at {fps} FPS")

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

    frame_count = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame_count += 1

        # Convert BGR to RGB as YOLOv5 expects RGB images
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Run object detection
        results = model(rgb_frame)

        # Each detection is [x1, y1, x2, y2, confidence, class]
        for *box, conf, cls in results.xyxy[0]:
            x1, y1, x2, y2 = map(int, box)
            conf = float(conf)
            class_idx = int(cls)
            label = f"{COCO_CLASSES[class_idx]} {conf:.2f}"
            # Draw bounding box
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            # Put label text
            cv2.putText(frame, label, (x1, max(y1 - 10, 0)),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        out.write(frame)

    cap.release()
    out.release()
    print(f"Processed video saved as '{output_path}'. Total frames: {frame_count}")

# Run detection on the uploaded video
detect_and_annotate_video(input_path=new_video_name)
# Out:
# Video properties: 640x480 at 30.0 FPS
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...

# %% [markdown]
# # Step 4: Display and download the output video in Colab

# %%
if os.path.exists("output_tracking.mp4"):
    display(Video("output_tracking.mp4", embed=True))
    print("Use the following to download the annotated video if needed:")
    from google.colab import files
    files.download("output_tracking.mp4")
else:
    print("Error: Failed to create 'output_tracking.mp4'!")
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
# Use the following to download the annotated video if needed:
